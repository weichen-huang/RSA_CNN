# %%
from brainscore_vision import score

model_score = score(model_identifier='alexnet', benchmark_identifier='Rajalingham2018-i2n')
print(model_score)
# Out:
# /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_core/metrics/__init__.py:16: FutureWarning: xarray subclass Score should explicitly define __slots__
#   class Score(DataAssembly):
# Requirement already satisfied: torch in ./venv/lib/python3.9/site-packages (from -r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 1)) (2.5.0.dev20240630)
# Requirement already satisfied: torchvision in ./venv/lib/python3.9/site-packages (from -r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 2)) (0.20.0.dev20240630)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.9/site-packages (from torch->-r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: fsspec in ./venv/lib/python3.9/site-packages (from torch->-r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 1)) (2024.6.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./venv/lib/python3.9/site-packages (from torch->-r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: filelock in ./venv/lib/python3.9/site-packages (from torch->-r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 1)) (3.15.4)
# Requirement already satisfied: networkx in ./venv/lib/python3.9/site-packages (from torch->-r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: sympy in ./venv/lib/python3.9/site-packages (from torch->-r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 1)) (1.13.0rc3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./venv/lib/python3.9/site-packages (from torchvision->-r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 2)) (10.3.0)
# Requirement already satisfied: numpy in ./venv/lib/python3.9/site-packages (from torchvision->-r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.9/site-packages (from jinja2->torch->-r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.9/site-packages (from sympy->torch->-r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/models/alexnet/requirements.txt (line 1)) (1.3.0)
# [notice] A new release of pip available: 22.3.1 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /Users/weichen/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:38<00:00, 6.37MB/s]
# Requirement already satisfied: numpy in ./venv/lib/python3.9/site-packages (from -r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/metrics/i1i2/requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: scipy in ./venv/lib/python3.9/site-packages (from -r /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/metrics/i1i2/requirements.txt (line 2)) (1.13.1)
# [notice] A new release of pip available: 22.3.1 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# brainio-brainscore/stimulus_objectome_public.csv: 100%|██████████| 270k/270k [00:00<00:00, 749kB/s]
# brainio-brainscore/stimulus_objectome_public.zip: 100%|██████████| 79.6M/79.6M [00:16<00:00, 4.80MB/s]
# activations:   0%|          | 0/2176 [00:00<?, ?it/s]
# layer packaging:   0%|          | 0/1 [00:00<?, ?it/s]
# /Users/weichen/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainio/fetch.py:78, in BotoFetcher.download_boto(self)
#      77     self._logger.debug("attempting default download (signed)")
# ---> 78     self.download_boto_config(config=None)
#      79 except Exception as e_signed:  # try without authentication
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainio/fetch.py:94, in BotoFetcher.download_boto_config(self, config)
#      93 # show progress. see https://gist.github.com/wy193777/e7607d12fad13459e8992d4f69b53586
# ---> 94 with tqdm(total=obj.content_length, unit='B', unit_scale=True,
#      95           desc=self.bucketname + "/" + self.relative_path) as progress_bar:
#      96     def progress_hook(bytes_amount):
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/boto3/resources/factory.py:381, in ResourceFactory._create_autoload_property.<locals>.property_loader(self)
#     380 if hasattr(self, 'load'):
# --> 381     self.load()
#     382 else:
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/boto3/resources/factory.py:565, in ResourceFactory._create_action.<locals>.do_action(self, *args, **kwargs)
#     564 def do_action(self, *args, **kwargs):
# --> 565     response = action(self, *args, **kwargs)
#     566     self.meta.data = response
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/boto3/resources/action.py:88, in ServiceAction.__call__(self, parent, *args, **kwargs)
#      81 logger.debug(
#      82     'Calling %s:%s with %r',
#      83     parent.meta.service_name,
#      84     operation_name,
#      85     params,
#      86 )
# ---> 88 response = getattr(parent.meta.client, operation_name)(*args, **params)
#      90 logger.debug('Response: %r', response)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/client.py:1001, in BaseClient._make_api_call(self, operation_name, api_params)
#    1000     apply_request_checksum(request_dict)
# -> 1001     http, parsed_response = self._make_request(
#    1002         operation_model, request_dict, request_context
#    1003     )
#    1005 self.meta.events.emit(
#    1006     'after-call.{service_id}.{operation_name}'.format(
#    1007         service_id=service_id, operation_name=operation_name
#    (...)
#    1012     context=request_context,
#    1013 )
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/client.py:1027, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1026 try:
# -> 1027     return self._endpoint.make_request(operation_model, request_dict)
#    1028 except Exception as e:
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     114 logger.debug(
#     115     "Making request for %s with params: %s",
#     116     operation_model,
#     117     request_dict,
#     118 )
# --> 119 return self._send_request(request_dict, operation_model)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/endpoint.py:198, in Endpoint._send_request(self, request_dict, operation_model)
#     197 self._update_retries_context(context, attempts)
# --> 198 request = self.create_request(request_dict, operation_model)
#     199 success_response, exception = self._get_response(
#     200     request, operation_model, context
#     201 )
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/endpoint.py:134, in Endpoint.create_request(self, params, operation_model)
#     131     event_name = 'request-created.{service_id}.{op_name}'.format(
#     132         service_id=service_id, op_name=operation_model.name
#     133     )
# --> 134     self._event_emitter.emit(
#     135         event_name,
#     136         request=request,
#     137         operation_name=operation_model.name,
#     138     )
#     139 prepared_request = self.prepare_request(request)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     411 aliased_event_name = self._alias_event_name(event_name)
# --> 412 return self._emitter.emit(aliased_event_name, **kwargs)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     246 """
#     247 Emit an event by name with arguments passed as keyword args.
#     248
#    (...)
#     254          handlers.
#     255 """
# --> 256 return self._emit(event_name, kwargs)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     238 logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239 response = handler(**kwargs)
#     240 responses.append((handler, response))
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/signers.py:105, in RequestSigner.handler(self, operation_name, request, **kwargs)
#     100 def handler(self, operation_name=None, request=None, **kwargs):
#     101     # This is typically hooked up to the "request-created" event
#     102     # from a client's event emitter.  When a new request is created
#     103     # this method is invoked to sign the request.
#     104     # Don't call this method directly.
# --> 105     return self.sign(operation_name, request)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/signers.py:199, in RequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     197         raise e
# --> 199 auth.add_auth(request)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/auth.py:418, in SigV4Auth.add_auth(self, request)
#     417 if self.credentials is None:
# --> 418     raise NoCredentialsError()
#     419 datetime_now = datetime.datetime.utcnow()
#
# NoCredentialsError: Unable to locate credentials
#
# During handling of the above exception, another exception occurred:
#
# ClientError                               Traceback (most recent call last)
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainio/fetch.py:84, in BotoFetcher.download_boto(self)
#      83 try:
# ---> 84     self.download_boto_config(config=unsigned_config)
#      85 except Exception as e_unsigned:
#      86     # when unsigned download also fails, raise both exceptions
#      87     # raise Exception instead of specific type to avoid missing __init__ arguments
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainio/fetch.py:94, in BotoFetcher.download_boto_config(self, config)
#      93 # show progress. see https://gist.github.com/wy193777/e7607d12fad13459e8992d4f69b53586
# ---> 94 with tqdm(total=obj.content_length, unit='B', unit_scale=True,
#      95           desc=self.bucketname + "/" + self.relative_path) as progress_bar:
#      96     def progress_hook(bytes_amount):
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/boto3/resources/factory.py:381, in ResourceFactory._create_autoload_property.<locals>.property_loader(self)
#     380 if hasattr(self, 'load'):
# --> 381     self.load()
#     382 else:
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/boto3/resources/factory.py:565, in ResourceFactory._create_action.<locals>.do_action(self, *args, **kwargs)
#     564 def do_action(self, *args, **kwargs):
# --> 565     response = action(self, *args, **kwargs)
#     566     self.meta.data = response
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/boto3/resources/action.py:88, in ServiceAction.__call__(self, parent, *args, **kwargs)
#      81 logger.debug(
#      82     'Calling %s:%s with %r',
#      83     parent.meta.service_name,
#      84     operation_name,
#      85     params,
#      86 )
# ---> 88 response = getattr(parent.meta.client, operation_name)(*args, **params)
#      90 logger.debug('Response: %r', response)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/botocore/client.py:1021, in BaseClient._make_api_call(self, operation_name, api_params)
#    1020     error_class = self.exceptions.from_code(error_code)
# -> 1021     raise error_class(parsed_response, operation_name)
#    1022 else:
#
# ClientError: An error occurred (403) when calling the HeadObject operation: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from brainscore_vision import score
# ----> 3 model_score = score(model_identifier='alexnet', benchmark_identifier='Rajalingham2018-i2n')
#       4 print(model_score)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/__init__.py:103, in score(model_identifier, benchmark_identifier, conda_active)
#      86 def score(model_identifier: str, benchmark_identifier: str, conda_active: bool = False) -> Score:
#      87     """
#      88     Score the model referenced by the `model_identifier` on the benchmark referenced by the `benchmark_identifier`.
#      89     The model needs to implement the :class:`~brainscore_vision.model_interface.BrainModel` interface
#    (...)
#     101         this benchmark's ceiling such that 1 means the model matches the data to ceiling level.
#     102     """
# --> 103     return wrap_score(__file__,
#     104                       model_identifier=model_identifier, benchmark_identifier=benchmark_identifier,
#     105                       score_function=_run_score, conda_active=conda_active)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_core/plugin_management/conda_score.py:88, in wrap_score(library_path, model_identifier, benchmark_identifier, score_function, conda_active)
#      86     result = conda_score()
#      87 else:
# ---> 88     result = score_function(model_identifier, benchmark_identifier)
#      89     CondaScore.save_score(result, Path(library_path), f'{model_identifier}_{benchmark_identifier}')
#      91 return result
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/__init__.py:76, in _run_score(model_identifier, benchmark_identifier)
#      74 model: BrainModel = load_model(model_identifier)
#      75 benchmark: Benchmark = load_benchmark(benchmark_identifier)
# ---> 76 score: Score = benchmark(model)
#      77 score.attrs['model_identifier'] = model_identifier
#      78 score.attrs['benchmark_identifier'] = benchmark_identifier
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/benchmarks/rajalingham2018/benchmarks/benchmark.py:42, in _DicarloRajalingham2018.__call__(self, candidate)
#      39 fitting_stimuli = place_on_screen(self._fitting_stimuli, target_visual_degrees=candidate.visual_degrees(),
#      40                                   source_visual_degrees=self._visual_degrees)
#      41 candidate.start_task(BrainModel.Task.probabilities, fitting_stimuli)
# ---> 42 stimulus_set = place_on_screen(self._assembly.stimulus_set, target_visual_degrees=candidate.visual_degrees(),
#      43                                source_visual_degrees=self._visual_degrees)
#      44 probabilities = candidate.look_at(stimulus_set, number_of_trials=self._number_of_trials)
#      45 score = self._metric(probabilities, self._assembly)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/utils/__init__.py:54, in LazyLoad.__getattr__(self, name)
#      53 def __getattr__(self, name):
# ---> 54     self._ensure_loaded()
#      55     return getattr(self.content, name)
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/utils/__init__.py:73, in LazyLoad._ensure_loaded(self)
#      71 def _ensure_loaded(self):
#      72     if self.content is None:
# ---> 73         self.content = self.load_fnc()
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/benchmarks/rajalingham2018/benchmarks/benchmark.py:29, in _DicarloRajalingham2018.__init__.<locals>.<lambda>()
#      27 self._metric = metric
#      28 self._fitting_stimuli = load_stimulus_set('objectome.public')
# ---> 29 self._assembly = LazyLoad(lambda: load_assembly('private'))
#      30 self._visual_degrees = 8
#      31 self._number_of_trials = 2
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/benchmarks/rajalingham2018/benchmarks/benchmark.py:72, in load_assembly(access)
#      71 def load_assembly(access='private'):
# ---> 72     assembly = load_dataset(f'Rajalingham2018.{access}')
#      73     assembly['correct'] = assembly['choice'] == assembly['sample_obj']
#      74     return assembly
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/__init__.py:34, in load_dataset(identifier)
#      31 def load_dataset(identifier: str) -> Union[DataAssembly, Any]:
#      32     import_plugin('brainscore_vision', 'data', identifier)
# ---> 34     return data_registry[identifier]()
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/data/rajalingham2018/__init__.py:30, in <lambda>()
#      20 data_registry['Rajalingham2018.public'] = lambda: load_assembly_from_s3(
#      21     identifier="dicarlo.Rajalingham2018.public",
#      22     version_id="WEBNb7Azz4CWpzO25JanNjdPSLArltS2",
#    (...)
#      26     stimulus_set_loader=lambda: load_stimulus_set('objectome.public'),
#      27 )
#      29 # private assembly: uses objectome.private stimuli
# ---> 30 data_registry['Rajalingham2018.private'] = lambda: load_assembly_from_s3(
#      31     identifier="dicarlo.Rajalingham2018.private",
#      32     version_id="gwBpHTT2al4FN35Yje7MU2d_ByA_HphX",
#      33     sha1="516f13793d1c5b72bb445bb4008448ce97a02d23",
#      34     bucket="brainio-brainscore",
#      35     cls=BehavioralAssembly,
#      36     stimulus_set_loader=lambda: load_stimulus_set('objectome.private'),
#      37 )
#      40 # stimulus set: objectome.public - rajalingham2018
#      41 stimulus_set_registry['objectome.public'] = lambda: load_stimulus_set_from_s3(
#      42     identifier="objectome.public",
#      43     bucket="brainio-brainscore",
#    (...)
#      46     csv_version_id="CwFzXLOclwodJZpInD6hc15yeTOywg6J",
#      47     zip_version_id="g.vVSa77K84jjeto5KAryLESzxJz0yUB")
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/data_helpers/s3.py:40, in load_assembly_from_s3(identifier, version_id, sha1, bucket, cls, stimulus_set_loader, merge_stimulus_set_meta)
#      37 def load_assembly_from_s3(identifier: str, version_id: str, sha1: str, bucket: str, cls: type,
#      38                           stimulus_set_loader: Callable[[], StimulusSet] = None,
#      39                           merge_stimulus_set_meta: bool = True) -> DataAssembly:
# ---> 40     file_path = get_path(identifier, 'nc', bucket, version_id, sha1)
#      41     if stimulus_set_loader:  # merge stimulus set meta into assembly if `stimulus_set_loader` is passed
#      42         stimulus_set = stimulus_set_loader()
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainscore_vision/data_helpers/s3.py:30, in get_path(identifier, file_type, bucket, version_id, sha1, filename_prefix)
#      27     filename_prefix = 'stimulus_' if file_type in ('csv', 'zip') else 'assy_'
#      29 filename = f"{filename_prefix}{identifier.replace('.', '_')}.{file_type}"
# ---> 30 file_path = fetch_file(location_type="S3",
#      31                        location=f"https://{bucket}.s3.amazonaws.com/{filename}",
#      32                        version_id=version_id,
#      33                        sha1=sha1)
#      34 return file_path
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainio/fetch.py:125, in fetch_file(location_type, location, sha1, version_id)
#     122 filename = filename_from_link(location)
#     123 fetcher = get_fetcher(type=location_type, location=location,
#     124                       local_filename=filename, version_id=version_id)
# --> 125 local_path = fetcher.fetch()
#     126 verify_sha1(local_path, sha1)
#     127 return local_path
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainio/fetch.py:71, in BotoFetcher.fetch(self)
#      69 def fetch(self):
#      70     if not os.path.exists(self.output_filename):
# ---> 71         self.download_boto()
#      72     return self.output_filename
#
# File ~/PycharmProjects/RSA_CNN/venv/lib/python3.9/site-packages/brainio/fetch.py:88, in BotoFetcher.download_boto(self)
#      84     self.download_boto_config(config=unsigned_config)
#      85 except Exception as e_unsigned:
#      86     # when unsigned download also fails, raise both exceptions
#      87     # raise Exception instead of specific type to avoid missing __init__ arguments
# ---> 88     raise Exception([e_signed, e_unsigned])
#
# Exception: [NoCredentialsError('Unable to locate credentials'), ClientError('An error occurred (403) when calling the HeadObject operation: Forbidden')]
